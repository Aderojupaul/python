# %%
class studentmanagement:
    def __init__ (self,name, gender,age,address,seatnumber):
        self.name = name
        self.gender = gender
        self.age = age
        self.address = address
        self.seatnumber = seatnumber
    def accept(self,NAME,GENDER,AGE,ADDRESS,SEATNUMBER):
        ob = studentmanagement(NAME,GENDER,AGE,ADDRESS,SEATNUMBER)
        studentrecords.append(ob)
    def display(self,ob):
        print(f'''NAME:{ob.name}
GENDER:{ob.gender}
AGE:{ob.age}
ADDRESS:{ob.address}
SEATNUMBER:{ob.seatnumber}
        ''')
    def search(self,sn):
        for i in range(len(studentrecords)):
            if(studentrecords[i].seatnumber == sn):
                return i 
    def update(self,sn,nsn):
        i = obj.search(sn)
        studentrecords[i].seatnumber = nsn
    def delete(self,sn):
        i = obj.search(sn)
        del(studentrecords[i])
        
studentrecords = []
obj = studentmanagement('','',0,'',0)
print('LIST OPERATIONS\naccept\ndisplay\nsearch\nupdate\ndelete')
operation = input('Enter y as yes to perform operation and n as no to terminate operation')
counter = 1
while operation == 'y':
    option = input('Enter operation options:')
    if option == 'accept':
        obj.accept(input('Student Name'),input('Customer Gender'),int(input('Student Age')),\
                   input('Student Address'),int(input('Student Seatnumber')))
    elif option == 'display':
        for i in range(len(studentrecords)):
            obj.display(studentrecords[i])
    elif option == 'search':
            s = obj.search(int(input('Enter seatnumber to search')))
            obj.display(studentrecords[s])
    elif option == 'update':
        obj.update(int(input('Enter seatnumber to update')),int(input('Enter seat new number')))
        for i in range(len(studentrecords)):
            obj.display(studentrecords[i])
    elif option == 'delete':
        obj.delete(int(input('Enter seatnumber to delete')))
        print(f'studentrecords has been deleted')
                   
    operation = input('Enter y as yes to perform operation and n as no to terminate operation')
                   
    counter = counter+1
# Out:
# LIST OPERATIONS
# accept
# display
# search
# update
# delete
# Enter y as yes to perform operation and n as no to terminate operationy
# Enter operation options:accept
# Student Namet
# Customer Gendert
# Student Age2
# Student Addresst
# Student Seatnumber2
# Enter y as yes to perform operation and n as no to terminate operationy
# Enter operation options:accept
# Student Namer
# Customer Genderr
# Student Age3
# Student Addressr
# Student Seatnumber3
# Enter y as yes to perform operation and n as no to terminate operationy
# Enter operation options:display
# NAME:t
#         GENDER:t
#         AGE:2
#         ADDRESS:t
#         SEATNUMBER:2
#
# NAME:r
#         GENDER:r
#         AGE:3
#         ADDRESS:r
#         SEATNUMBER:3
#
# Enter y as yes to perform operation and n as no to terminate operationy
# Enter operation options:search
# Enter seatnumber to search2
# NAME:t
#         GENDER:t
#         AGE:2
#         ADDRESS:t
#         SEATNUMBER:2
#
# ...
