# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GDP.csv')
df.head()
# Out:
#    tyear  Period  Agriculture  CropProduction  Livestock  Forestry   Fishing  \
# 0   1981  Annual   2364373.15      1854764.44  341411.50  77897.99  90299.23
# 1   1982  Annual   2425960.89      1897078.85  361115.70  73910.25  93856.08
# 2   1983  Annual   2409081.92      1842704.31  393131.01  75282.78  97963.82
# 3   1984  Annual   2303505.42      1759115.15  399685.38  76694.14  68010.74
# 4   1985  Annual   2731062.47      2180907.71  428102.85  78082.45  43969.46
#
#      Industry  CrudePetroleumAndNaturalGas  SolidMinerals  ...  \
# 0  6603250.12                   4977416.70       67136.73  ...
# 1  6272828.03                   4453093.63       54840.50  ...
# 2  5264881.39                   4052977.68       44014.84  ...
# 3  5621181.44                   4559196.21       43078.37  ...
# 4  6379599.38                   4918272.50       44539.09  ...
#
#    ArtsEntertainmentAndRecreation  FinanceAndInsurance  RealEstate  \
# ...

# %%
df.isnull().sum()
# Out:
# tyear                                               0
# Period                                              0
# Agriculture                                         0
# CropProduction                                      0
# Livestock                                           0
# Forestry                                            0
# Fishing                                             0
# Industry                                            0
# CrudePetroleumAndNaturalGas                         0
# SolidMinerals                                       0
# Manufacturing                                       0
# Construction                                        0
# Services                                            0
# Trade                                               0
# AccommodationAndFoodServices                        0
# Transport                                           0
# InformationAndCommunication                         0
# ...

# %%
plt.plot(df['tyear'],df['Agriculture'])

# %%
df = df[df['Period']== 'Annual']
plt.style.use('ggplot')
plt.plot(df['tyear'],df['Agriculture'], ls = 'dotted', lw = '3.5',marker = '+', markevery = 4, label = 'GDP')
plt.xlabel('YEAR')
plt.ylabel('AGRICULTURE')
plt.title('TREND OF AGRICULTURE GDP IN MILLIONS')
plt.legend()
plt.savefig('TREND.png')
plt.show()

# %%
plt.style.use('ggplot')
plt.plot(df['tyear'],df['Agriculture'], ls = 'dotted', lw = '3.5',marker = '+', markevery = 4, label = 'AGRIC', color='green')
plt.plot(df['tyear'],df['Education'], ls = 'dotted', lw = '3.5',marker = '+', markevery = 4, label = 'EDUC', color = 'blue')
plt.plot(df['tyear'],df['CrudePetroleumAndNaturalGas'], ls = 'dotted', lw = '3.5',marker = '+', markevery = 4, label = 'CRUDE OIL', color='yellow')
plt.plot(df['tyear'],df['InformationAndCommunication'], ls = 'dotted', lw = '3.5',marker = '+', markevery = 4, label = 'ICT', color='red')
plt.xlabel('YEAR')
plt.ylabel('GDP')
plt.title('TREND OF VARIOUS INDUSTRIES GDP IN MILLIONS')
plt.legend(loc=[1,0])
plt.savefig('TREND2.png')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.bar(df['tyear'],df['Education'],color='red')
# Out:
# <BarContainer object of 38 artists>

# %%
fig = plt.figure(figsize=(15,15))
axes = fig.add_axes([0.1,0.1,0.5,0.3])
axes.bar(df['tyear'],df['Agriculture'],color = 'blue')
axes.set_xlabel('YEAR',fontsize = 35,color = 'blue')
axes.set_ylabel('GDP',fontsize = 35,color = 'blue')
axes.set_title('COMPARISM OF AGRICULTURAL GDP OVER THE YEAR', fontsize = 18, color = 'blue')
for label in axes.get_xticklabels():
    label.set_color('blue')
for label in axes.get_yticklabels():
    label.set_color('blue')
plt.show()

# %%
fig,axes = plt.subplots(2,3, figsize = (25,15))
axes[0][0].plot(df['tyear'],df['Agriculture'], color='navy')
axes[0][0].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[0][0].set_ylabel('AGRICULTURAL GDP',fontsize = 15,color = 'blue')
axes[0][0].set_title('TREND OF AGRICULTURAL GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[0][0].get_xticklabels():
    label.set_color('blue')
for label in axes[0][0].get_yticklabels():
    label.set_color('blue')
    
axes[0][1].plot(df['tyear'],df['Education'], color='navy')
axes[0][1].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[0][1].set_ylabel('EDUCATIONAL GDP',fontsize = 15,color = 'blue')
axes[0][1].set_title('TREND OF EDUCATIONAL GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[0][1].get_xticklabels():
    label.set_color('blue')
for label in axes[0][1].get_yticklabels():
    label.set_color('blue')
    
axes[0][2].plot(df['tyear'],df['Fishing'], color='navy')
axes[0][2].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[0][2].set_ylabel('FISHING GDP',fontsize = 15,color = 'blue')
axes[0][2].set_title('TREND OF FISHING GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[0][2].get_xticklabels():
    label.set_color('blue')
for label in axes[0][2].get_yticklabels():
    label.set_color('blue')
    
axes[1][0].plot(df['tyear'],df['Construction'], color='navy')
axes[1][0].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[1][0].set_ylabel('CONSTRUCTION GDP',fontsize = 15,color = 'blue')
axes[1][0].set_title('TREND OF CONSTRUCTION GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[1][0].get_xticklabels():
    label.set_color('blue')
for label in axes[1][0].get_yticklabels():
    label.set_color('blue')
    
axes[1][1].plot(df['tyear'],df['Forestry'], color='navy')
axes[1][1].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[1][1].set_ylabel('FORESTRY GDP',fontsize = 15,color = 'blue')
axes[1][1].set_title('TREND OF FORESTRY GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[1][1].get_xticklabels():
    label.set_color('blue')
for label in axes[1][1].get_yticklabels():
    label.set_color('blue')
    
axes[1][2].plot(df['tyear'],df['Industry'], color='navy')
axes[1][2].set_xlabel('YEAR',fontsize = 15,color = 'blue')
axes[1][2].set_ylabel('INDUSTRY GDP',fontsize = 15,color = 'blue')
axes[1][2].set_title('TREND OF INDUSTRY GDP OVER THE YEAR', fontsize = 15, color = 'blue')
for label in axes[1][2].get_xticklabels():
    label.set_color('blue')
for label in axes[1][2].get_yticklabels():
    label.set_color('blue')
